# %%
import numpy as np
import tensorflow as tf

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from vision.vAE import VAE

# %%
path = os.getcwd()
path = path[:-6] + 'data/rr_data_state.npz'
rand_data = np.load(path)['arr_0']
print(rand_data.shape)
# Out:
# (258, 1000, 1, 64, 64, 1)

# %%
rand_data = np.reshape(rand_data, (rand_data.shape[0]*rand_data.shape[1], 64, 64, 1))
rand_data.shape
# Out:
# (258000, 64, 64, 1)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.imshow(rand_data[420], cmap="gray")
plt.show()

# %%
ds = tf.data.Dataset.from_tensor_slices(rand_data[50000:100000])
ds = ds.map(lambda x: tf.cast(x, tf.float32))
ds = ds.shuffle(32).batch(265).prefetch(tf.data.experimental.AUTOTUNE)
print(ds)
# Out:
# <PrefetchDataset shapes: (None, 64, 64, 1), types: tf.float32>

# %%
len(ds)
# Out:
# 189

# %%
def compare_images(input,model,n_images):
  """iterate over n_images images and plot original vs. reconstruction"""

  for i_n in input.take(n_images):

    input = np.reshape(i_n[0].numpy(),(1,64,64,1))
    noise = np.random.normal(loc=0.0, scale=1.0, size=input.shape)
    noisy_input = np.clip(input + 0.25 * noise, 0., 1.)
    output = model(noisy_input)

    print("Loss on following test example: " + str(model.loss(input)['reconstruction-loss']))
    fig,ax = plt.subplots(ncols = 3)

    # we plot the original images on the very left to be able to draw a comparison
    ax[0].imshow(tf.squeeze(input))
    ax[0].set_title("Original Input")
    ax[0].axis('off')

    # in the middle, we add noise to the input, which we use for training
    ax[1].imshow(tf.squeeze(noisy_input))
    ax[1].set_title("Input + Noise")
    ax[1].axis('off')

    # on the right side, we plot the reconstruction of the original image from the noisy input
    ax[2].imshow(tf.squeeze(output))
    ax[2].set_title("Reconstructed Output")
    ax[2].axis('off')

    plt.show()

# %%
def train(model, data, epochs):
    losses = []
    batch_loss = []

    for epoch in range(epochs):

        for batch in data:
            batch_loss.append(np.mean(v.backward(batch)['reconstruction-loss']))
        losses.append(np.mean(batch_loss))
        
        print(f"Epoch: {epoch} done - Loss: {losses[-1]}")
        compare_images(ds, v, 1)
        
    model.save(os.getcwd())
        
    return losses

# %%
v = VAE()

losses = train(v, ds, 1)

compare_images(ds, v, 5)
# Out:
# Epoch: 0 done - Loss: 725.572265625
# Loss on following test example: tf.Tensor(3763.5977, shape=(), dtype=float32)
# saving model to /Users/floyd/Documents/Studium/Coxi6/DRL/World-Model-LunarLanderContinuous-v2-with-PPO/world_model/vision/models
# Loss on following test example: tf.Tensor(403.19086, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(212.48473, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(482.50128, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(493.68427, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(217.0726, shape=(), dtype=float32)

# %%
losses = train(v, ds, 16)

compare_images(ds, v, 5)
# Out:
# Epoch: 0 done - Loss: 361.18011474609375
# Loss on following test example: tf.Tensor(2801.8389, shape=(), dtype=float32)
# Epoch: 1 done - Loss: 318.6522521972656
# Loss on following test example: tf.Tensor(317.89117, shape=(), dtype=float32)
# Epoch: 2 done - Loss: 291.33233642578125
# Loss on following test example: tf.Tensor(2371.9478, shape=(), dtype=float32)
# Epoch: 3 done - Loss: 273.86016845703125
# Loss on following test example: tf.Tensor(307.45392, shape=(), dtype=float32)
# Epoch: 4 done - Loss: 261.7164001464844
# Loss on following test example: tf.Tensor(5238.926, shape=(), dtype=float32)
# Epoch: 5 done - Loss: 252.66236877441406
# Loss on following test example: tf.Tensor(2167.601, shape=(), dtype=float32)
# Epoch: 6 done - Loss: 245.51309204101562
# Loss on following test example: tf.Tensor(2888.4363, shape=(), dtype=float32)
# Epoch: 7 done - Loss: 239.68218994140625
# Loss on following test example: tf.Tensor(176.84033, shape=(), dtype=float32)
# ...

# %%
vtwo = VAE()
for batch in ds.take(1):
    _ = vtwo(batch)
vtwo.load(os.getcwd())

compare_images(ds, vtwo, 5)
# Out:
# loading model from /Users/floyd/Documents/Studium/Coxi6/DRL/World-Model-LunarLanderContinuous-v2-with-PPO/world_model/vision/models
# Loss on following test example: tf.Tensor(200.72505, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(98.67984, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(198.83153, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(143.86926, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(97.002106, shape=(), dtype=float32)

# %%
lossssss = train(vtwo, ds, 4)
# Out:
# Epoch: 0 done - Loss: 159.2733612060547
# Loss on following test example: tf.Tensor(162.12595, shape=(), dtype=float32)
# Epoch: 1 done - Loss: 159.53948974609375
# Loss on following test example: tf.Tensor(231.98885, shape=(), dtype=float32)
# Epoch: 2 done - Loss: 159.22625732421875
# Loss on following test example: tf.Tensor(335.63257, shape=(), dtype=float32)
# Epoch: 3 done - Loss: 158.93731689453125
# Loss on following test example: tf.Tensor(186.93152, shape=(), dtype=float32)
# saving model to /Users/floyd/Documents/Studium/Coxi6/DRL/World-Model-LunarLanderContinuous-v2-with-PPO/world_model/vision/models

# %%
## fig,ax = plt.subplots()

for img in ds.take(1):
    img = np.reshape(img[0].numpy(),(1,64,64,1))
    output = v(img)

    ax.imshow(tf.squeeze(output))
    ax.set_title("Reconstructed Output")
    ax.axis('off')

    plt.show()

# %%
loss = train(v, ds.take(10), 1)
# Out:
# Epoch: 0 done
# Loss on following test example: tf.Tensor(2999.1416, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(183.10062, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(170.37079, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(145.74377, shape=(), dtype=float32)
# Loss on following test example: tf.Tensor(130.95937, shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-c3969093b694> in <module>
# ----> 1 loss = train(v, ds.take(10), 1)
#
# <ipython-input-53-072ea8fc8036> in train(model, data, epochs)
#       5
#       6         for batch in data:
# ----> 7             loss = v.backward(batch)
#       8             losses.append(np.mean(loss['reconstruction-loss']))
#       9             #print("Batch loss: ", losses[-1])
#
# ...
